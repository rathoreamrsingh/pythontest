# %%
import tweepy
from tweepy.streaming import StreamListener
from textblob import TextBlob
import csv
from nltk.tokenize import word_tokenize
import collections
from collections import defaultdict

# %%
consumer_key='zZWPaXgIgmohaSfFOM8U8xMu1'
consumer_secret='6qMhIv4LUMKYw9JRn386AxudWQCN6NWGQ5WgOiiuDn2csTYq8D'

access_token='2264037373-So8YG6aVSLKgHaNGVGKoiaK3yJBxphunxgkY0Qd'
access_token_secret='eJ0rzDnqhOZ5O1uQFVOaszEhM3SAASaa9OybbYGLpVQjg'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %%
company_name='amzn'
search_tag='amazoncustomercare'
public_tweets = api.search(search_tag)
positive = {}
negative = {}
neutral = {}
for tweet in public_tweets:
    #print('======================================')
    #print(tweet.text)
    analysis = TextBlob(tweet.text)
    #print(analysis.sentiment)
    #print(analysis.sentiment.polarity)
    #analysis.tags
    print("INSERT INTO twitter_sentimental_analysis (company_code, tweet, polarity, subjectivity) values (" +"'IBM'"+ ",'"+tweet.text.replace("\'", "\\'")+"'," +str(analysis.sentiment.polarity) +","+str(analysis.sentiment.subjectivity) + ");")
    print('\n')
    for i in word_tokenize(tweet.text):
        if(len(i) != 1 and i.isalpha()):
            if(analysis.sentiment.polarity < 0):
                if(i.upper() not in negative):
                    negative[i.upper()]=1
                else:
                    negative[i.upper()]+=1
            elif(analysis.sentiment.polarity == 0):
                if(i.upper() not in neutral):
                    neutral[i.upper()]=1
                else:
                    neutral[i.upper()]+=1
            else:
                if(i.upper() not in positive):
                    positive[i.upper()]=1
                else:
                    positive[i.upper()]+=1
        
c = collections.Counter(final)

for key, value in neutral.items():
    print('\n')
    print("INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES (" + "'"+company_name.upper()+"'"+",'"+key+"',"+""+str(value)+",0);")


for key, value in negative.items():
    print('\n')
    print("INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES (" + "'"+company_name.upper()+"'"+",'"+key+"',"+""+str(value)+",-1);")


for key, value in positive.items():
    print('\n')
    print("INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES (" + "'"+company_name.upper()+"'"+",'"+key+"',"+""+str(value)+",1);")
# Out:
# INSERT INTO twitter_sentimental_analysis (company_code, tweet, polarity, subjectivity) values ('IBM','#amazon #amazonin are you sleeping? #amazoncustomercare',0.0,0.0);
#
#
# INSERT INTO twitter_sentimental_analysis (company_code, tweet, polarity, subjectivity) values ('IBM','On 05th of June 2018, I ordered a Pigeon All In One Super Cooker, 3 Liters(Black) bearing order no. 402-7600750-292… https://t.co/CorOvUFwco',0.3333333333333333,0.6666666666666666);
#
#
# INSERT INTO twitter_sentimental_analysis (company_code, tweet, polarity, subjectivity) values ('IBM','@amazonIN why you guys acting so wired! Help me please 😣 #AmazonIndia #amazoncustomercare #noonecares',0.0,0.0);
#
#
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','AMAZON',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','AMAZONIN',2,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','ARE',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','YOU',2,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','SLEEPING',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','AMAZONCUSTOMERCARE',2,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','WHY',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','GUYS',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','ACTING',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','SO',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','WIRED',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','HELP',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','ME',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','PLEASE',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','AMAZONINDIA',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','NOONECARES',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','ON',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','OF',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','JUNE',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','ORDERED',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','PIGEON',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','ALL',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','IN',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','ONE',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','SUPER',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','COOKER',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','LITERS',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','BLACK',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','BEARING',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','ORDER',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','NO',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('AMZN','HTTPS',1,1);
