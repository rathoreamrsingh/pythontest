# %%
import tweepy
from tweepy.streaming import StreamListener
from textblob import TextBlob
import csv

# %%
consumer_key='zZWPaXgIgmohaSfFOM8U8xMu1'
consumer_secret='6qMhIv4LUMKYw9JRn386AxudWQCN6NWGQ5WgOiiuDn2csTYq8D'

access_token='2264037373-So8YG6aVSLKgHaNGVGKoiaK3yJBxphunxgkY0Qd'
access_token_secret='eJ0rzDnqhOZ5O1uQFVOaszEhM3SAASaa9OybbYGLpVQjg'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
api = tweepy.API(auth)

public_tweets = api.search('ibm')

for tweet in public_tweets:
    print('======================================')
    print(tweet)
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
    print(analysis.sentiment.polarity)
    print(analysis.sentiment.subjectivity)
    print('======================================')
# Out:
# ======================================
# #IBM, #Mediaocean Partner to Tackle Ad Industry Opacity with #Blockchain https://t.co/Fv0iHpfcYZ https://t.co/5xK59JMZCO
# Sentiment(polarity=0.0, subjectivity=0.0)
# 0.0
# 0.0
# ======================================
# ======================================
# IBM and Mediaocean Are Creating a Blockchain Ecosystem to Track Spending
#
# https://t.co/nCB8viqtK8
# Sentiment(polarity=0.0, subjectivity=0.0)
# 0.0
# 0.0
# ======================================
# ======================================
# IBM has committed to a hybrid cloud strategy &amp; built an (IaaS) platform that can offer the versatility of public cl… https://t.co/nKyzC4NeXM
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# 0.0
# 0.06666666666666667
# ======================================
# ======================================
# RT @MikeStuchbery_: The Nazi Party turned to Dehomag, the German branch of IBM to help them track &amp; trace Jews.
#
# Their Hollerith machines,…
# Sentiment(polarity=0.0, subjectivity=0.0)
# 0.0
# 0.0
# ======================================
# ======================================
# RT @JohnWhite: IBM’s @RashikParmar discusses AI , Quantum Computing and unlocking the potential of #ConnectedBritain https://t.co/IZUiONoMPw
# Sentiment(polarity=0.0, subjectivity=1.0)
# 0.0
# 1.0
# ======================================
# ======================================
# IBM has committed to a hybrid cloud strategy &amp; built an (IaaS) platform that can offer the versatility of public cl… https://t.co/Ad0D61sq0p
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# 0.0
# 0.06666666666666667
# ======================================
# ======================================
# IBM has committed to a hybrid cloud strategy &amp; built an (IaaS) platform that can offer the versatility of public cl… https://t.co/9A2OMe68Pl
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# 0.0
# 0.06666666666666667
# ======================================
# ======================================
# IBM has committed to a hybrid cloud strategy &amp; built an (IaaS) platform that can offer the versatility of public cl… https://t.co/St6zfCBESI
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# 0.0
# 0.06666666666666667
# ======================================
# ======================================
# IBM has committed to a hybrid cloud strategy &amp; built an (IaaS) platform that can offer the versatility of public cl… https://t.co/cYDVsRoH2k
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# 0.0
# 0.06666666666666667
# ======================================
# ======================================
# RT @kashthefuturist: Debate between AI and humans
# #future #robots #AI #data #TechTrends #IoT #technology #ConnectedDevices #automation
# @JG…
# Sentiment(polarity=0.0, subjectivity=0.125)
# 0.0
# 0.125
# ======================================
# ======================================
# IBM has committed to a hybrid cloud strategy &amp; built an (IaaS) platform that can offer the versatility of public cl… https://t.co/VvOF7A3evN
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# 0.0
# 0.06666666666666667
# ======================================
# ======================================
# RT @IBMSecurity: TOMORROW: Join @IBM experts to learn how MaaS360 is changing the game for unified endpoint management by graphing apps and…
# Sentiment(polarity=-0.4, subjectivity=0.4)
# -0.4
# 0.4
# ======================================
# ======================================
# RT @MikeStuchbery_: The Nazi Party turned to Dehomag, the German branch of IBM to help them track &amp; trace Jews.
#
# Their Hollerith machines,…
# Sentiment(polarity=0.0, subjectivity=0.0)
# 0.0
# 0.0
# ======================================
# ======================================
# IBM has committed to a hybrid cloud strategy &amp; built an (IaaS) platform that can offer the versatility of public cl… https://t.co/pZgabcq1tV
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# 0.0
# 0.06666666666666667
# ======================================
# ======================================
# IBM has committed to a hybrid cloud strategy &amp; built an (IaaS) platform that can offer the versatility of public cl… https://t.co/wwvjcTmxNC
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# 0.0
# 0.06666666666666667
# ======================================
