# %%
import tweepy
from tweepy.streaming import StreamListener
from textblob import TextBlob
import csv
from nltk.tokenize import word_tokenize
import collections
from collections import defaultdict

# %%
consumer_key='zZWPaXgIgmohaSfFOM8U8xMu1'
consumer_secret='6qMhIv4LUMKYw9JRn386AxudWQCN6NWGQ5WgOiiuDn2csTYq8D'

access_token='2264037373-So8YG6aVSLKgHaNGVGKoiaK3yJBxphunxgkY0Qd'
access_token_secret='eJ0rzDnqhOZ5O1uQFVOaszEhM3SAASaa9OybbYGLpVQjg'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %%
company_name='ibm'
search_tag='ibmwatson'
public_tweets = api.search(search_tag)
positive = {}
negative = {}
neutral = {}
for tweet in public_tweets:
    #print('======================================')
    #print(tweet.text)
    analysis = TextBlob(tweet.text)
    #print(analysis.sentiment)
    #print(analysis.sentiment.polarity)
    #analysis.tags
    print("INSERT INTO twitter_sentimental_analysis (company_code, tweet, polarity, subjectivity) values (" +"'IBM'"+ ",'"+tweet.text.replace("\'", "\\'")+"'," +str(analysis.sentiment.polarity) +","+str(analysis.sentiment.subjectivity) + ");")
    print('\n')
    for i in word_tokenize(tweet.text):
        if(len(i) != 1 and i.isalpha()):
            if(analysis.sentiment.polarity < 0):
                if(i.upper() not in negative):
                    negative[i.upper()]=1
                else:
                    negative[i.upper()]+=1
            elif(analysis.sentiment.polarity == 0):
                if(i.upper() not in neutral):
                    neutral[i.upper()]=1
                else:
                    neutral[i.upper()]+=1
            else:
                if(i.upper() not in positive):
                    positive[i.upper()]=1
                else:
                    positive[i.upper()]+=1
        
c = collections.Counter(final)

for key, value in neutral.items():
    print('\n')
    print("INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES (" + "'"+company_name.upper()+"'"+",'"+key+"',"+""+str(value)+",0);")


for key, value in negative.items():
    print('\n')
    print("INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES (" + "'"+company_name.upper()+"'"+",'"+key+"',"+""+str(value)+",-1);")


for key, value in positive.items():
    print('\n')
    print("INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES (" + "'"+company_name.upper()+"'"+",'"+key+"',"+""+str(value)+",1);")
# Out:
# INSERT INTO twitter_sentimental_analysis (company_code, tweet, polarity, subjectivity) values ('IBM','RT @IBMNews: Project CIMON, an AI assistant powered by @IBMWatson, is heading into space tomorrow to assist the crew with daily tasks aboar…',0.0,0.0);
#
#
# INSERT INTO twitter_sentimental_analysis (company_code, tweet, polarity, subjectivity) values ('IBM','RT @IBM: #IBMWatson intelligently distributes renewable energy to a network of batteries, helping balance the grid. https://t.co/ivJjeoi9DS',0.8,0.9);
#
#
# INSERT INTO twitter_sentimental_analysis (company_code, tweet, polarity, subjectivity) values ('IBM','Now isn’t this amazing! #ibm #whatwedo #makeadifference #ibmwatson #watchuswork https://t.co/RhBhxufc8a',0.7500000000000001,0.9);
#
#
# INSERT INTO twitter_sentimental_analysis (company_code, tweet, polarity, subjectivity) values ('IBM','@arlemi @IBMWatson Hey thanks for the reply!
#
# It turns out it was a weird edge case issue for folks upgrading from… https://t.co/WAaTLVf7WP',-0.125,0.6);
#
#
# INSERT INTO twitter_sentimental_analysis (company_code, tweet, polarity, subjectivity) values ('IBM','With power comes responsiblity, responsibility to unblock true progress. #ResponsibleBusiness https://t.co/wrRCeaO4gR',0.35,0.65);
#
#
# INSERT INTO twitter_sentimental_analysis (company_code, tweet, polarity, subjectivity) values ('IBM','RT @DrMorey1: #China looks to #AI to save #Healthcare system #technology #MachineLearning @IBMWatson
# #IBM #Watson
#
# https://t.co/tccpU57DLV',0.0,0.0);
#
#
# INSERT INTO twitter_sentimental_analysis (company_code, tweet, polarity, subjectivity) values ('IBM','RT @IBMWatson: This #AI-powered assistant is embarking on a mission tomorrow to join astronauts on the International @Space_Station. Meet #…',0.0,0.0);
#
#
# INSERT INTO twitter_sentimental_analysis (company_code, tweet, polarity, subjectivity) values ('IBM','RT @IBMNews: Project CIMON, an AI assistant powered by @IBMWatson, is heading into space tomorrow to assist the crew with daily tasks aboar…',0.0,0.0);
#
#
# INSERT INTO twitter_sentimental_analysis (company_code, tweet, polarity, subjectivity) values ('IBM','RT @astro_cimon: Want to watch me 🤖 roaring into Space🚀? Read more: NASA Television to Air Launch of Next Space Station Resupply Mission #C…',0.25,0.25);
#
#
# INSERT INTO twitter_sentimental_analysis (company_code, tweet, polarity, subjectivity) values ('IBM','RT @IBMWatson: Interested in virtual reality gaming? By using Watson\'s Speech to Text and SDK for Unity, @RedStorm enhanced the user experi…',0.25,0.5);
#
#
# INSERT INTO twitter_sentimental_analysis (company_code, tweet, polarity, subjectivity) values ('IBM','RT @IBMNews: Project CIMON, an AI assistant powered by @IBMWatson, is heading into space tomorrow to assist the crew with daily tasks aboar…',0.0,0.0);
#
#
# INSERT INTO twitter_sentimental_analysis (company_code, tweet, polarity, subjectivity) values ('IBM','RT @russelljohns: Carla Arend, IDC drilling deep into the digital organisation and multi-cloud at the Cloud&amp;Data Summit, essential for AI a…',0.0,0.2333333333333333);
#
#
# INSERT INTO twitter_sentimental_analysis (company_code, tweet, polarity, subjectivity) values ('IBM','Interested in virtual reality gaming? By using Watson\'s Speech to Text and SDK for Unity, RedStorm enhanced the use… https://t.co/wR9r2XKTHr',0.25,0.5);
#
#
# INSERT INTO twitter_sentimental_analysis (company_code, tweet, polarity, subjectivity) values ('IBM','Interested in virtual reality gaming? By using Watson\'s Speech to Text and SDK for Unity, RedStorm enhanced the use… https://t.co/qmMZjG9FTY',0.25,0.5);
#
#
# INSERT INTO twitter_sentimental_analysis (company_code, tweet, polarity, subjectivity) values ('IBM','#China looks to #AI to save #Healthcare system #technology #MachineLearning @IBMWatson
# #IBM #Watson
#
# https://t.co/tccpU57DLV',0.0,0.0);
#
#
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','RT',6,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','IBMNEWS',3,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','PROJECT',3,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','CIMON',3,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','AN',3,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','AI',6,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','ASSISTANT',4,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','POWERED',3,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','BY',3,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','IBMWATSON',6,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','IS',4,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','HEADING',3,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','INTO',4,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','SPACE',3,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','TOMORROW',4,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','TO',8,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','ASSIST',3,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','THE',6,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','CREW',3,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','WITH',3,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','DAILY',3,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','TASKS',3,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','CHINA',2,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','LOOKS',2,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','SAVE',2,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','HEALTHCARE',2,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','SYSTEM',2,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','TECHNOLOGY',2,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','MACHINELEARNING',2,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','IBM',2,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','WATSON',2,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','HTTPS',2,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','THIS',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','EMBARKING',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','ON',2,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','MISSION',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','JOIN',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','ASTRONAUTS',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','INTERNATIONAL',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','MEET',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','RUSSELLJOHNS',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','CARLA',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','AREND',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','IDC',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','DRILLING',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','DEEP',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','DIGITAL',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','ORGANISATION',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','AND',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','AT',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','CLOUD',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','AMP',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','DATA',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','SUMMIT',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','ESSENTIAL',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','FOR',1,0);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','ARLEMI',1,-1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','IBMWATSON',1,-1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','HEY',1,-1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','THANKS',1,-1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','FOR',2,-1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','THE',1,-1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','REPLY',1,-1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','IT',2,-1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','TURNS',1,-1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','OUT',1,-1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','WAS',1,-1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','WEIRD',1,-1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','EDGE',1,-1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','CASE',1,-1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','ISSUE',1,-1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','FOLKS',1,-1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','UPGRADING',1,-1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','HTTPS',1,-1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','RT',3,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','IBM',2,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','IBMWATSON',3,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','INTELLIGENTLY',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','DISTRIBUTES',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','RENEWABLE',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','ENERGY',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','TO',7,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','NETWORK',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','OF',2,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','BATTERIES',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','HELPING',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','BALANCE',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','THE',4,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','GRID',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','HTTPS',5,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','NOW',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','ISN',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','THIS',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','AMAZING',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','WHATWEDO',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','MAKEADIFFERENCE',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','WATCHUSWORK',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','WITH',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','POWER',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','COMES',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','RESPONSIBLITY',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','RESPONSIBILITY',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','UNBLOCK',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','TRUE',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','PROGRESS',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','RESPONSIBLEBUSINESS',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','WANT',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','WATCH',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','ME',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','ROARING',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','INTO',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','READ',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','MORE',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','NASA',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','TELEVISION',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','AIR',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','LAUNCH',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','NEXT',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','SPACE',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','STATION',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','RESUPPLY',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','MISSION',1,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','INTERESTED',3,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','IN',3,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','VIRTUAL',3,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','REALITY',3,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','GAMING',3,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','BY',3,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','USING',3,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','WATSON',3,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','SPEECH',3,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','TEXT',3,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','AND',3,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','SDK',3,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','FOR',3,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','UNITY',3,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','REDSTORM',3,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','ENHANCED',3,1);
#
#
# INSERT INTO WORD_MAP(COMPANY_CODE, WORD, COUNT, POLARITY) VALUES ('IBM','USER',1,1);
